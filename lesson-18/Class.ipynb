# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot([1,2,3,5,2.6])

# %%
plt.plot([2,1.5,6],[2,2,7])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 plt.plot([2,1.5,6],[2,2,7,8])
#
# File w:\Users\sardo\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\pyplot.py:3829, in plot(scalex, scaley, data, *args, **kwargs)
#    3821 @_copy_docstring_and_deprecators(Axes.plot)
#    3822 def plot(
#    3823     *args: float | ArrayLike | str,
#    (...)
#    3827     **kwargs,
#    3828 ) -> list[Line2D]:
# -> 3829     return gca().plot(
#    3830         *args,
#    3831         scalex=scalex,
#    3832         scaley=scaley,
#    3833         **({"data": data} if data is not None else {}),
#    3834         **kwargs,
#    3835     )
#
# File w:\Users\sardo\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\axes\_axes.py:1777, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1534 """
# ...

# %%
plt.plot([1,1,10,10,1,10,15,15,22,22,22,24,27,30,33,27,33,36],[1,30,30,1,1,1,1,30,1,30,1,1,17,30,17,17,17,1])

# %%
fig = plt.figure()

# %%
ax1 = fig.add_subplot(2,2,1)

# %%
fig

# %%
ax2 = fig.add_subplot(2,2,2)

# %%
ax4 = fig.add_subplot(5,3,4)

# %%
fig

# %%
ax3 = fig.add_subplot(4,2,5)

# %%
fig

# %%
ax1.hist(np.random.rand(100), bins=20)
# Out:
# (array([6., 5., 2., 3., 3., 7., 4., 5., 8., 6., 8., 1., 8., 2., 6., 1., 6.,
#         5., 6., 8.]),
#  array([0.00970556, 0.05856539, 0.10742521, 0.15628504, 0.20514487,
#         0.25400469, 0.30286452, 0.35172435, 0.40058417, 0.449444  ,
#         0.49830383, 0.54716365, 0.59602348, 0.64488331, 0.69374314,
#         0.74260296, 0.79146279, 0.84032262, 0.88918244, 0.93804227,
#         0.9869021 ]),
#  <BarContainer object of 20 artists>)

# %%
fig

# %%
plt.plot(np.random.randn(50),'rD-' )

# %%
ax2.scatter(np.arange(30), np.arange(30)+3*np.random.randn(30))

# %%
fig

# %%
data = np.random.randn(30)*10
print(data)
plt.plot(data, 'k--', label = 'ABC')
# Out:
# [  4.74450167   6.3562718  -15.90448939  -8.57700427   1.00849561
#   -2.97797616  -3.77046266  -7.9802816   -5.02906418  16.19847886
#   10.16371096  -4.18290288   1.84240701  -6.07623874  -2.37693119
#    0.61452623 -11.57074995   4.06643063  14.325515     1.72497251
#   -2.8318757   12.14845945 -25.00472972   7.87915834 -18.42680373
#    6.38554269  -4.50332981  -2.70095763 -13.18099621 -13.27466077]

# %%
plt.plot(data, 'b-', drawstyle = 'steps-post')

# %%
import pandas as pd

df = pd.DataFrame(np.random.randn(10,4), columns = ['A', 'B', 'C' , 'D'])
df.plot()
# Out:
# <Axes: >

# %%
fig , axes = plt.subplots(2,1)

data = pd.Series(np.random.randn(16), index = list('dwdwefefdsasefdw'))

# %%
tips = pd.read_csv('tips.csv')


# tips.plot(columns = ['tip'])

smokes = tips['smoker'].value_counts()
# tips['smokers']

plt.pie(smokes, labels=smokes.index)
plt.show()
