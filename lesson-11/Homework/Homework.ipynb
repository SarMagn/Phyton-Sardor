# %%
class Student:
    def __init__(self, student_id, student_name):
        self.student_id = student_id
        self.student_name = student_name
        self.courses_students = []
    
    def __str__(self) -> str: 
        return f'Student_id: {self.student_id}, Name: {self.student_name} '
    
    def enroll_course(self, course):
        self.courses_students.append(course)
    
    def display_courses(self):
        print(f'{self.student_name}\'s following: ')
        for course in self.courses_students:
            print(course)
        

Jack = Student(1 , 'Jackson')
Jack.enroll_course('Geography')
Jack.display_courses()
Jack.__str__()
# Out:
# Jackson's following:
# Geography
# 'Student_id: 1, Name: Jackson '

# %%
class Course:
    def __init__(self, course_id, course_name):
        self.course_id = course_id
        self.course_name = course_name

    def __str__(self) -> str:
        return f'Course Id: {self.course_id}, Course Name: {self.course_name}'

# %%
class StudentList:
    def __init__(self):
        self.students = []

    def add_student(self, student):
        self.students.append(student)

    def list_students(self):
        print("List of students: ")
        for student in self.students:
            print(student)

    def search_student(self, student_id):
        for student in self.students:
            if student.student_id == student_id:
                return student
        return None

# %%
def print_menu():
    print("Welcome to Student Information menu")
    print("1.Add a new student")
    print('2.List all students')
    print("3.Enroll a student in a course")
    print("4.Display course for a student")
    print("5.Exit")

def main():
    students_List = StudentList()

    while True:
        print_menu()
        choice = input("Enter your choice: 1 - 5")

        if choice == '1':
            student_id = input("Enter student ID: ")
            student_name = input("Enter Student Name: ")
            student = Student(student_id, student_name)
            students_List.add_student(student)
            print('Student {studant_name} have been added successfully')
        elif choice == '2':
            students_List.list_students()
        elif choice == '3':
            id = input("Enter Student ID: ")
            student = students_List.search_student(student_id)
            if student:
                course_id = input("Enter course id: ")
                course_name = input("Enter course name: ")
                course = Course(course_id,course_name)
                student.enroll_course(course)
                print(f"Student {student.name} enrolled in {course_name} successfully")
            else:
                print(f'Student with ID{student_id} not found')

        elif choice == '4':
            id = input("Enter student ID: ")
            student = students_List.search_student(student_id)
            if student:
                student.display_courses()
            else:
                print(f'Student with ID {student_id} not found ')
        elif choice == '5':
            print('Exiting the program')
            break

        else:
            print('Please enter numbers between 1 and 5 ')


main()
# Out:
# Welcome to Student Information menu
# 1.Add a new student
# 2.List all students
# 3.Enroll a student in a course
# 4.Display course for a student
# 5.Exit
# Student {studant_name} have been added successfully
# Welcome to Student Information menu
# 1.Add a new student
# 2.List all students
# 3.Enroll a student in a course
# 4.Display course for a student
# 5.Exit
# List of students:
# ...
# Welcome to Student Information menu
# 1.Add a new student
# 2.List all students
# 3.Enroll a student in a course
# 4.Display course for a student
# 5.Exit
# List of students:
# ...
# Welcome to Student Information menu
# 1.Add a new student
# 2.List all students
# 3.Enroll a student in a course
# 4.Display course for a student
# 5.Exit

# %%
class Student:
    def __init__(self, student_id, student_name):
        self.student_id = student_id
        self.student_name = student_name
        self.courses_students = []
    
    def __str__(self) -> str: 
        return f'Student_id: {self.student_id}, Name: {self.student_name}'
    
    def enroll_course(self, course):
        self.courses_students.append(course)
    
    def display_courses(self):
        print(f'{self.student_name}\'s following courses: ')
        for course in self.courses_students:
            print(course)
        

class Course: 
    def __init__(self, course_id, course_name):
        self.course_id = course_id
        self.course_name = course_name

    def __str__(self) -> str:
        return f'Course Id: {self.course_id}, Course Name: {self.course_name}'


class StudentList: 
    def __init__(self):
        self.students = []
    
    def add_student(self, student):
        self.students.append(student)

    def list_students(self):
        print("List of students: ")
        for student in self.students:
            print(student)  # This will use the __str__ method

    def search_student(self, student_id):
        for student in self.students:
            if student.student_id == student_id:
                return student
        return None


def print_menu(): 
    print("Welcome to Student Information menu")
    print("1. Add a new student")
    print("2. List all students")
    print("3. Enroll a student in a course")
    print("4. Display courses for a student")
    print("5. Exit")


def main():
    students_list = StudentList()

    while True:
        print_menu()
        choice = input("Enter your choice: 1 - 5: ")

        if choice == '1':
            student_id = input("Enter student ID: ")
            student_name = input("Enter Student Name: ")
            student = Student(student_id, student_name)
            students_list.add_student(student)
            print(f'Student {student_name} has been added successfully')
        
        elif choice == '2':
            students_list.list_students()  # This will print the students using the __str__ method
        
        elif choice == '3':
            student_id = input("Enter Student ID: ")
            student = students_list.search_student(student_id)
            if student:
                course_id = input("Enter course ID: ")
                course_name = input("Enter course name: ")
                course = Course(course_id, course_name)
                student.enroll_course(course)
                print(f"Student {student.student_name} enrolled in {course_name} successfully")
            else:
                print(f'Student with ID {student_id} not found')

        elif choice == '4':
            student_id = input("Enter student ID: ")
            student = students_list.search_student(student_id)
            if student:
                student.display_courses()
            else:
                print(f'Student with ID {student_id} not found')
        
        elif choice == '5':
            print('Exiting the program')
            break

        else:
            print('Please enter a number between 1 and 5')

main()

# %%
class Post:
    def __init__(self, title, content, author):
        self.title = title
        self.content = content
        self.author = author

    def __str__(self):
        return f'{self.title} has this {self.content} by author: {self.author}'

x = Post('Data analytics','Python','Sardor')

print(x)

# class Blog:
#     def addpost():
#         in

# x.content
# Out:
# Data analytics has this Python by author: Sardor
