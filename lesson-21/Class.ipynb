# %%
import pan

# %%
import pandas as pd

# %%
with open ('movie.csv') as data_file:
    data = data_file.readlines(1)
    print(data)
# Out:
# ['color,director_name,num_critic_for_reviews,duration,director_facebook_likes,actor_3_facebook_likes,actor_2_name,actor_1_facebook_likes,gross,genres,actor_1_name,movie_title,num_voted_users,cast_total_facebook_likes,actor_3_name,facenumber_in_poster,plot_keywords,movie_imdb_link,num_user_for_reviews,language,country,content_rating,budget,title_year,actor_2_facebook_likes,imdb_score,aspect_ratio,movie_facebook_likes\n']

# %%
movies = pd.read_csv('movie.csv')
movies
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 4911  Color        Scott Smith                     1.0      87.0
# 4912  Color                NaN                    43.0      43.0
# 4913  Color   Benjamin Roberds                    13.0      76.0
# 4914  Color        Daniel Hsia                    14.0     100.0
# 4915  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
movies.head(6)
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
# 5  Color     Andrew Stanton                   462.0     132.0
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
# 5                    475.0                   530.0   Samantha Morton
#
# ...

# %%
movies.tail()
# Out:
#       color     director_name  num_critic_for_reviews  duration  \
# 4911  Color       Scott Smith                     1.0      87.0
# 4912  Color               NaN                    43.0      43.0
# 4913  Color  Benjamin Roberds                    13.0      76.0
# 4914  Color       Daniel Hsia                    14.0     100.0
# 4915  Color          Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 4911                      2.0                   318.0     Daphne Zuniga
# 4912                      NaN                   319.0     Valorie Curry
# 4913                      0.0                     0.0     Maxwell Moody
# 4914                      0.0                   489.0     Daniel Henney
# 4915                     16.0                    16.0  Brian Herzlinger
#
#       actor_1_facebook_likes    gross                        genres  ...  \
# ...

# %%
columns = movies.columns
columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
index = movies.index
index
# Out:
# RangeIndex(start=0, stop=4916, step=1)

# %%
values = movies.values
values
# Out:
# array([['Color', 'James Cameron', 723.0, ..., 7.9, 1.78, 33000],
#        ['Color', 'Gore Verbinski', 302.0, ..., 7.1, 2.35, 0],
#        ['Color', 'Sam Mendes', 602.0, ..., 6.8, 2.35, 85000],
#        ...,
#        ['Color', 'Benjamin Roberds', 13.0, ..., 6.3, nan, 16],
#        ['Color', 'Daniel Hsia', 14.0, ..., 6.3, 2.35, 660],
#        ['Color', 'Jon Gunn', 43.0, ..., 6.6, 1.85, 456]],
#       shape=(4916, 28), dtype=object)

# %%
print(type(columns))
print(type(index))
print(type(values))
# Out:
# <class 'pandas.core.indexes.base.Index'>
# <class 'pandas.core.indexes.range.RangeIndex'>
# <class 'numpy.ndarray'>

# %%
#DataFrame 
#Series

# %%
movies.dtypes
# Out:
# color                         object
# director_name                 object
# num_critic_for_reviews       float64
# duration                     float64
# director_facebook_likes      float64
# actor_3_facebook_likes       float64
# actor_2_name                  object
# actor_1_facebook_likes       float64
# gross                        float64
# genres                        object
# actor_1_name                  object
# movie_title                   object
# num_voted_users                int64
# cast_total_facebook_likes      int64
# actor_3_name                  object
# facenumber_in_poster         float64
# plot_keywords                 object
# movie_imdb_link               object
# num_user_for_reviews         float64
# language                      object
# country                       object
# content_rating                object
# budget                       float64
# title_year                   float64
# actor_2_facebook_likes       float64
# ...

# %%
movies.dtypes.value_counts()
# Out:
# float64    13
# object     12
# int64       3
# Name: count, dtype: int64

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4916 entries, 0 to 4915
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      4897 non-null   object
#  1   director_name              4814 non-null   object
#  2   num_critic_for_reviews     4867 non-null   float64
#  3   duration                   4901 non-null   float64
#  4   director_facebook_likes    4814 non-null   float64
#  5   actor_3_facebook_likes     4893 non-null   float64
#  6   actor_2_name               4903 non-null   object
#  7   actor_1_facebook_likes     4909 non-null   float64
#  8   gross                      4054 non-null   float64
#  9   genres                     4916 non-null   object
#  10  actor_1_name               4909 non-null   object
#  11  movie_title                4916 non-null   object
#  12  num_voted_users            4916 non-null   int64
# ...

# %%
import numpy as np

# %%
pd.Series(['Apple',None ,'Pear', np.nan])
# Out:
# 0    Apple
# 1     None
# 2     Pear
# 3      NaN
# dtype: object

# %%
movies['director_name']
# Out:
# 0           James Cameron
# 1          Gore Verbinski
# 2              Sam Mendes
# 3       Christopher Nolan
# 4             Doug Walker
#               ...
# 4911          Scott Smith
# 4912                  NaN
# 4913     Benjamin Roberds
# 4914          Daniel Hsia
# 4915             Jon Gunn
# Name: director_name, Length: 4916, dtype: object

# %%
movies.director_name
# Out:
# 0           James Cameron
# 1          Gore Verbinski
# 2              Sam Mendes
# 3       Christopher Nolan
# 4             Doug Walker
#               ...
# 4911          Scott Smith
# 4912                  NaN
# 4913     Benjamin Roberds
# 4914          Daniel Hsia
# 4915             Jon Gunn
# Name: director_name, Length: 4916, dtype: object

# %%
movies['director_name'].index
# Out:
# RangeIndex(start=0, stop=4916, step=1)

# %%
movies[['director_name', 'duration']].head(2)
# Out:
#     director_name  duration
# 0   James Cameron     178.0
# 1  Gore Verbinski     169.0

# %%
movies['director_name'].name
# Out:
# 'director_name'

# %%
movies['director_name'].unique()
# Out:
# array(['James Cameron', 'Gore Verbinski', 'Sam Mendes', ...,
#        'Scott Smith', 'Benjamin Roberds', 'Daniel Hsia'],
#       shape=(2398,), dtype=object)

# %%
direactor  = movies['director_name']

# %%
movies.sample(n=2)
# Out:
#       color  director_name  num_critic_for_reviews  duration  \
# 2480  Color  Antoine Fuqua                   197.0     132.0
# 3781  Color   Andrew Erwin                    49.0      98.0
#
#       director_facebook_likes  actor_3_facebook_likes actor_2_name  \
# 2480                    847.0                   625.0  Lili Taylor
# 3781                     10.0                   402.0   Sarah Drew
#
#       actor_1_facebook_likes       gross                genres  ...  \
# 2480                  3000.0  27154426.0  Crime|Drama|Thriller  ...
# 3781                   589.0  10429707.0                Comedy  ...
#
#      num_user_for_reviews language  country  content_rating      budget  \
# 2480                138.0  English      USA               R  17000000.0
# 3781                125.0  English      USA              PG   5000000.0
#
#       title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 2480      2009.0                  960.0        6.7          2.35
# ...

# %%
direactor.sample(n=5)
# Out:
# 2031        Irvin Kershner
# 900         Jonathan Demme
# 1008    David Gordon Green
# 1551          Don Scardino
# 3493       Stephen Sommers
# Name: director_name, dtype: object

# %%
direactor.value_counts()  # har bitta direktorni nechta kinosi borligini chiqaaradi
# Out:
# director_name
# Steven Spielberg      26
# Woody Allen           22
# Clint Eastwood        20
# Martin Scorsese       20
# Spike Lee             16
#                       ..
# Mike Bruce             1
# Bradley Rust Gray      1
# Collin Joseph Neal     1
# Kirk Loudon            1
# Kevin Jordan           1
# Name: count, Length: 2397, dtype: int64

# %%
fb_likes  = movies['actor_1_facebook_likes']

# %%
fb_likes
# Out:
# 0        1000.0
# 1       40000.0
# 2       11000.0
# 3       27000.0
# 4         131.0
#          ...
# 4911      637.0
# 4912      841.0
# 4913        0.0
# 4914      946.0
# 4915       86.0
# Name: actor_1_facebook_likes, Length: 4916, dtype: float64

# %%
fb_likes.value_counts()
# Out:
# actor_1_facebook_likes
# 1000.0     436
# 11000.0    206
# 2000.0     189
# 3000.0     150
# 12000.0    131
#           ...
# 375.0        1
# 318.0        1
# 630.0        1
# 10.0         1
# 291.0        1
# Name: count, Length: 877, dtype: int64

# %%
print(fb_likes.max())
# Out:
# 640000.0

# %%
fb_likes.min()
# Out:
# np.float64(0.0)

# %%
direactor.isna()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4911    False
# 4912     True
# 4913    False
# 4914    False
# 4915    False
# Name: director_name, Length: 4916, dtype: bool

# %%
direactor.isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4911    False
# 4912     True
# 4913    False
# 4914    False
# 4915    False
# Name: director_name, Length: 4916, dtype: bool

# %%
direactor.fillna("Ma'lumot yo'q")
# Out:
# 0           James Cameron
# 1          Gore Verbinski
# 2              Sam Mendes
# 3       Christopher Nolan
# 4             Doug Walker
#               ...
# 4911          Scott Smith
# 4912        Ma'lumot yo'q
# 4913     Benjamin Roberds
# 4914          Daniel Hsia
# 4915             Jon Gunn
# Name: director_name, Length: 4916, dtype: object

# %%
fb_likes.dropna()
# Out:
# 0        1000.0
# 1       40000.0
# 2       11000.0
# 3       27000.0
# 4         131.0
#          ...
# 4911      637.0
# 4912      841.0
# 4913        0.0
# 4914      946.0
# 4915       86.0
# Name: actor_1_facebook_likes, Length: 4909, dtype: float64

# %%
imdb_score = movies['imdb_score']

# %%
aa = imdb_score + 8

# %%
aa
# Out:
# 0       15.9
# 1       15.1
# 2       14.8
# 3       16.5
# 4       15.1
#         ...
# 4911    15.7
# 4912    15.5
# 4913    14.3
# 4914    14.3
# 4915    14.6
# Name: imdb_score, Length: 4916, dtype: float64

# %%
imdb_score > 2
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 4911    True
# 4912    True
# 4913    True
# 4914    True
# 4915    True
# Name: imdb_score, Length: 4916, dtype: bool

# %%
money = pd.Series([100, 20 , None])
money
# Out:
# 0    100.0
# 1     20.0
# 2      NaN
# dtype: float64

# %%
money - 16
# Out:
# 0    84.0
# 1     4.0
# 2     NaN
# dtype: float64

# %%
money.sub(15, fill_value=0)
# Out:
# 0    85.0
# 1     5.0
# 2   -15.0
# dtype: float64

# %%
money.fillna(0)  - 11
# Out:
# 0    89.0
# 1     9.0
# 2   -11.0
# dtype: float64

# %%
secondMoney = pd.Series([50,10])
secondMoney
# Out:
# 0    50
# 1    10
# dtype: int64

# %%
money + secondMoney
# Out:
# 0    150.0
# 1     30.0
# 2      NaN
# dtype: float64

# %%
fb_likes.fillna(0).astype(int)
# Out:
# 0        1000
# 1       40000
# 2       11000
# 3       27000
# 4         131
#         ...
# 4911      637
# 4912      841
# 4913        0
# 4914      946
# 4915       86
# Name: actor_1_facebook_likes, Length: 4916, dtype: int64

# %%
movies.rename(columns={"director_name":"director",
              "num_critic_for_reviews":"Critic_reviews"})
# Out:
#       color           director  Critic_reviews  duration  \
# 0     Color      James Cameron           723.0     178.0
# 1     Color     Gore Verbinski           302.0     169.0
# 2     Color         Sam Mendes           602.0     148.0
# 3     Color  Christopher Nolan           813.0     164.0
# 4       NaN        Doug Walker             NaN       NaN
# ...     ...                ...             ...       ...
# 4911  Color        Scott Smith             1.0      87.0
# 4912  Color                NaN            43.0      43.0
# 4913  Color   Benjamin Roberds            13.0      76.0
# 4914  Color        Daniel Hsia            14.0     100.0
# 4915  Color           Jon Gunn            43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# 1                       563.0                  1000.0     Orlando Bloom
# ...

# %%
movies['viewed']= 0

# %%
movies
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 4911  Color        Scott Smith                     1.0      87.0
# 4912  Color                NaN                    43.0      43.0
# 4913  Color   Benjamin Roberds                    13.0      76.0
# 4914  Color        Daniel Hsia                    14.0     100.0
# 4915  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
movies.drop(columns="viewed", inplace=True)

# %%
movies
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 4911  Color        Scott Smith                     1.0      87.0
# 4912  Color                NaN                    43.0      43.0
# 4913  Color   Benjamin Roberds                    13.0      76.0
# 4914  Color        Daniel Hsia                    14.0     100.0
# 4915  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
fname = ['McAte', 'Fade', 'Richard', 'Wieh']
lname = ['Freddite','Valve','Stark','Timati']
birth = [2005,1996,1958,1989]

people  = pd.DataFrame({"FirstName": fname, "LastName": lname, "Birth": birth})
people
# Out:
#   FirstName  LastName  Birth
# 0     McAte  Freddite   2005
# 1      Fade     Valve   1996
# 2   Richard     Stark   1958
# 3      Wieh    Timati   1989

# %%
df = pd.read_csv('weather_data.csv')

max = df['temp'].max()

print(f'Max is {max}'  )

avg =  df['temp'].mean()

print(f'Average is {avg}')
# Out:
# Max is 20
# Average is 14.0

# %%
a = df[df.day == 'Monday']
a['condition']
# Out:
# 0    Sunny
# Name: condition, dtype: object

# %%
# Out:
#          day  temp condition
# 0     Monday     8     Sunny
# 1    Tuesday    11      Rain
# 2  Wednesday    12      Rain
# 3   Thursday    11    Cloudy
# 4     Friday    19     Sunny
# 5   Saturday    17     Sunny
# 6     Sunday    20     Sunny

# %%
import pandas as pd 


df = pd.read_csv('movie.csv')


tit = df.to_excel('Titanic.xlsx',sheet_name='Passengers',index=False)
