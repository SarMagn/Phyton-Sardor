# %% [markdown]
# HomeTask 1

# %%
import pandas as pd

data = {'Fisrt Name': ['Alice','Bob','Charlie','David'],
        'Age':[25,30,35,40],
        'City':['New York','San Francisco','Los Angeles','Chicago']}
df = pd.DataFrame(data)

# %%
df = df.rename(columns={'Fisrt Name':'first_name','Age':'age'})

# %%
df.head(3)
# Out:
#   first_name  age           City
# 0      Alice   25       New York
# 1        Bob   30  San Francisco
# 2    Charlie   35    Los Angeles

# %%
print(df['age'].mean())
# Out:
# 32.5

# %%
df[['first_name','City']]
# Out:
#   first_name           City
# 0      Alice       New York
# 1        Bob  San Francisco
# 2    Charlie    Los Angeles
# 3      David        Chicago

# %%
import numpy as np


df['salary'] = np.random.randint(0,1000,size=len(df))
print(df)
# Out:
#   first_name  age           City  salary
# 0      Alice   25       New York     224
# 1        Bob   30  San Francisco     985
# 2    Charlie   35    Los Angeles     641
# 3      David   40        Chicago     975

# %%
import pandas as pd
import sqlalchemy as sql

connection = sql.create_engine(r'mssql+pyodbc://Sardors-laptop\SQLSERVER2025/master?driver=ODBC+Driver+17+for+SQL+Server').connect()

df = pd.read_sql_table('lag',connection)
df
# Out:
#    BusinessEntityID  SalesYear  CurrentQuota
# 0               275       2005      367000.0
# 1               275       2005      556000.0
# 2               275       2006      502000.0
# 3               275       2006      550000.0
# 4               275       2006     1429000.0
# 5               275       2006     1324000.0

# %%
df.describe()
# Out:
#              age     salary
# count   4.000000    4.00000
# mean   32.500000  706.25000
# std     6.454972  359.05002
# min    25.000000  224.00000
# 25%    28.750000  536.75000
# 50%    32.500000  808.00000
# 75%    36.250000  977.50000
# max    40.000000  985.00000

# %% [markdown]
# Homework 2

# %%
data = pd.DataFrame({'Month':['Jan','Feb','Mar','Apr'],
                    'Sales':[5000,6000,7500,8000],
                    'Expenses':[3000,3500,4000,4500]})
data
# Out:
#   Month  Sales  Expenses
# 0   Jan   5000      3000
# 1   Feb   6000      3500
# 2   Mar   7500      4000
# 3   Apr   8000      4500

# %%
data[['Sales','Expenses']].max()
# Out:
# Sales       8000
# Expenses    4500
# dtype: int64

# %%
data[['Sales','Expenses']].min()
# Out:
# Sales       5000
# Expenses    3000
# dtype: int64

# %%
data[['Sales','Expenses']].mean()
# Out:
# Sales       6625.0
# Expenses    3750.0
# dtype: float64

# %% [markdown]
# Homework - 3

# %%
df['rank'] = range(1,len(df)+1)
df
# Out:
#    BusinessEntityID  SalesYear  CurrentQuota  rank
# 0               275       2005      367000.0     1
# 1               275       2005      556000.0     2
# 2               275       2006      502000.0     3
# 3               275       2006      550000.0     4
# 4               275       2006     1429000.0     5
# 5               275       2006     1324000.0     6

# %%
df_new = df.merge(df, left_on='rank', right_on=df['rank']+1, how='left' )
df_new[['BusinessEntityID_x','SalesYear_x','CurrentQuota_x','CurrentQuota_y']]
# Out:
#    BusinessEntityID_x  SalesYear_x  CurrentQuota_x  CurrentQuota_y
# 0                 275         2005        367000.0             NaN
# 1                 275         2005        556000.0        367000.0
# 2                 275         2006        502000.0        556000.0
# 3                 275         2006        550000.0        502000.0
# 4                 275         2006       1429000.0        550000.0
# 5                 275         2006       1324000.0       1429000.0

# %%
import pandas as pd
import sqlalchemy as sql


connection = sql.create_engine(r'mssql+pyodbc://Sardors-laptop\SQLSERVER2025/master?driver=ODBC+Driver+17+for+SQL+Server').connect()
data1 = pd.read_sql_table('lag2',connection)
data1
# Out:
#    BusinessEntityID  SalesYear  CurrentQuota
# 0               275       2005      367000.0
# 1               275       2005      556000.0
# 2               275       2006      502000.0
# 3               275       2006      550000.0
# 4               275       2006     1429000.0
# 5               275       2006     1324000.0

# %%
data1['row_num'] = range(1, len(data1)+1)
data1 = data1.merge(data1,left_on='row_num',right_on=data1['row_num']-1,how='left', suffixes=('_first','_sec'))
data1
# Out:
#    row_num  BusinessEntityID_first  SalesYear_first  CurrentQuota_first  \
# 0        1                     275             2005            367000.0
# 1        2                     275             2005            556000.0
# 2        3                     275             2006            502000.0
# 3        4                     275             2006            550000.0
# 4        5                     275             2006           1429000.0
# 5        6                     275             2006           1324000.0
#
#    row_num_first  BusinessEntityID_sec  SalesYear_sec  CurrentQuota_sec  \
# 0              1                 275.0         2005.0          556000.0
# 1              2                 275.0         2006.0          502000.0
# 2              3                 275.0         2006.0          550000.0
# 3              4                 275.0         2006.0         1429000.0
# 4              5                 275.0         2006.0         1324000.0
# ...

# %%
data1[['BusinessEntityID_first','SalesYear_first','CurrentQuota_first','CurrentQuota_sec']]
# Out:
#    BusinessEntityID_first  SalesYear_first  CurrentQuota_first  \
# 0                     275             2005            367000.0
# 1                     275             2005            556000.0
# 2                     275             2006            502000.0
# 3                     275             2006            550000.0
# 4                     275             2006           1429000.0
# 5                     275             2006           1324000.0
#
#    CurrentQuota_sec
# 0          556000.0
# 1          502000.0
# 2          550000.0
# 3         1429000.0
# 4         1324000.0
# 5               NaN

# %%
import pandas as pd 
import sqlalchemy as sql

connection = sql.create_engine(r'mssql+pyodbc://Sardors-laptop\SQLSERVER2025/master?driver=ODBC+Driver+17+for+SQL+Server').connect()
connection
df = pd.read_sql_table('EmpBirth',connection)
df
# Out:
#    EmpId  EmpName  BirthDate
# 0      1    Pawan 1983-12-04
# 1      2     Zuzu 1986-11-28
# 2      3  Parveen 1977-05-07
# 3      4   Mahesh 1983-01-13
# 4      5   Ramesh 1983-05-09

# %%
df
# Out:
#    EmpId  EmpName  BirthDate
# 0      1    Pawan 1983-12-04
# 1      2     Zuzu 1986-11-28
# 2      3  Parveen 1977-05-07
# 3      4   Mahesh 1983-01-13
# 4      5   Ramesh 1983-05-09

# %%
df[(df['BirthDate'].dt.month == 5) & (df['BirthDate'].dt.day <= 15) & (df['BirthDate'].dt.day >= 7 ) ]
# Out:
#    EmpId  EmpName  BirthDate
# 2      3  Parveen 1977-05-07
# 4      5   Ramesh 1983-05-09

# %%
import pandas as pd

# %%
data = pd.read_sql_table('Movie',connection)
data
# Out:
#   MName    AName   Roles
# 0     A  Amitabh   Actor
# 1     A    Vinod  Villan
# 2     B  Amitabh   Actor
# 3     B    Vinod   Actor
# 4     D  Amitabh   Actor
# 5     E    Vinod   Actor

# %%
filtered = data[
    (data['AName'].isin(['Vinod', 'Amitabh'])) &
    (data['Roles'] == 'Actor') &
    (data['MName'].isin(data.loc[data['AName'] == 'Vinod', 'MName']) & 
     data['MName'].isin(data.loc[data['AName'] == 'Amitabh', 'MName']))
]
filtered
# Out:
#   MName    AName  Roles
# 0     A  Amitabh  Actor
# 2     B  Amitabh  Actor
# 3     B    Vinod  Actor
