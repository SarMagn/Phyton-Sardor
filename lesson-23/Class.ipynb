# %%
# Given a string that contain characterss, find the first non-repeating letter
# If there is no such letter, return None.
# 'H' and 'h' are considered the same
# Do not use extra data structures like dictionaries, lists, or sets to store or count frequencies, also do not use while .


sample_string1 = "eat the egg!"  
sample_string2 = "eat, ate       !"
sample_string3 = "Hi, he said nothing! Or did he?"

# %%
string = []
def String_return(x):
    strings = x.split()
    for i in strings:
        


String_return(sample_string1)
# Out:
# ['e', 'a', 't', 't', 'h', 'e', 'e', 'g', 'g', '!']

# %%
import pandas as pd
import numpy as np
import sqlalchemy as sa

# %%
college = pd.read_csv(r'W:\Users\sardo\OneDrive\Desktop\Maab and Data Analytics\Phyton-Sardor\lesson-23\college.csv')
college
# Out:
#                                                  INSTNM              CITY  \
# 0                              Alabama A & M University            Normal
# 1                   University of Alabama at Birmingham        Birmingham
# 2                                    Amridge University        Montgomery
# 3                   University of Alabama in Huntsville        Huntsville
# 4                              Alabama State University        Montgomery
# ...                                                 ...               ...
# 7530         SAE Institute of Technology  San Francisco        Emeryville
# 7531                  Rasmussen College - Overland Park     Overland Park
# 7532  National Personal Training Institute of Cleveland  Highland Heights
# 7533  Bay Area Medical Academy - San Jose Satellite ...          San Jose
# 7534            Excel Learning Center-San Antonio South       San Antonio
#
#      STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# ...

# %%
college.head()
# Out:
#                                 INSTNM        CITY STABBR  HBCU  MENONLY  \
# 0             Alabama A & M University      Normal     AL   1.0      0.0
# 1  University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# 2                   Amridge University  Montgomery     AL   0.0      0.0
# 3  University of Alabama in Huntsville  Huntsville     AL   0.0      0.0
# 4             Alabama State University  Montgomery     AL   1.0      0.0
#
#    WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  \
# 0        0.0         0     424.0     420.0           0.0  ...     0.0000
# 1        0.0         0     570.0     565.0           0.0  ...     0.0368
# 2        0.0         1       NaN       NaN           1.0  ...     0.0000
# 3        0.0         0     595.0     590.0           0.0  ...     0.0172
# 4        0.0         0     425.0     430.0           0.0  ...     0.0098
#
#    UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# ...

# %%
db_url = r'mssql+pyodbc://Sardors-laptop\SQLSERVER2025/master?driver=ODBC Driver 17 for SQL Server'
engine = sa.create_engine(db_url)
connection = engine.connect()

# %%
college.to_sql('college',con=engine,index=False,if_exists='replace')
# Out:
# 66

# %%
df = pd.read_sql(sa.text('select * from college'),con=connection)
df
# Out:
#                                                  INSTNM              CITY  \
# 0                              Alabama A & M University            Normal
# 1                   University of Alabama at Birmingham        Birmingham
# 2                                    Amridge University        Montgomery
# 3                   University of Alabama in Huntsville        Huntsville
# 4                              Alabama State University        Montgomery
# ...                                                 ...               ...
# 7530         SAE Institute of Technology  San Francisco        Emeryville
# 7531                  Rasmussen College - Overland Park     Overland Park
# 7532  National Personal Training Institute of Cleveland  Highland Heights
# 7533  Bay Area Medical Academy - San Jose Satellite ...          San Jose
# 7534            Excel Learning Center-San Antonio South       San Antonio
#
#      STABBR  HBCU  MENONLY  WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# ...

# %%
df.drop_duplicates(subset='CITY',keep='last')
# Out:
#                                                   INSTNM              CITY  \
# 7541                   Central Alabama Community College    Alexander City
# 7549                  Enterprise State Community College        Enterprise
# 7550            James H Faulkner State Community College       Bay Minette
# 7552                     Gadsden State Community College           Gadsden
# 7553                New Beginning College of Cosmetology       Albertville
# ...                                                  ...               ...
# 15065         SAE Institute of Technology  San Francisco        Emeryville
# 15066                  Rasmussen College - Overland Park     Overland Park
# 15067  National Personal Training Institute of Cleveland  Highland Heights
# 15068  Bay Area Medical Academy - San Jose Satellite ...          San Jose
# 15069            Excel Learning Center-San Antonio South       San Antonio
#
# ...

# %%
college = pd.read_csv(r'W:\Users\sardo\OneDrive\Desktop\Maab and Data Analytics\Phyton-Sardor\lesson-23\college.csv',index_col = 'INSTNM')
college
# Out:
#                                                                 CITY STABBR  \
# INSTNM
# Alabama A & M University                                      Normal     AL
# University of Alabama at Birmingham                       Birmingham     AL
# Amridge University                                        Montgomery     AL
# University of Alabama in Huntsville                       Huntsville     AL
# Alabama State University                                  Montgomery     AL
# ...                                                              ...    ...
# SAE Institute of Technology  San Francisco                Emeryville     CA
# Rasmussen College - Overland Park                      Overland Park     KS
# National Personal Training Institute of Cleveland   Highland Heights     OH
# Bay Area Medical Academy - San Jose Satellite L...          San Jose     CA
# Excel Learning Center-San Antonio South                  San Antonio     TX
#
# ...

# %%
movie = pd.read_csv(r'W:\Users\sardo\OneDrive\Desktop\Maab and Data Analytics\Phyton-Sardor\lesson-23\movie.csv')
movie
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 4911  Color        Scott Smith                     1.0      87.0
# 4912  Color                NaN                    43.0      43.0
# 4913  Color   Benjamin Roberds                    13.0      76.0
# 4914  Color        Daniel Hsia                    14.0     100.0
# 4915  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
criteria1 = movie.imdb_score > 8
criteria2 = movie.content_rating == 'PG-13'
criteria3 = (movie.title_year < 2000) | (movie.title_year > 2009)
criteria_final1 = (criteria1 & criteria2 & criteria3)

criteria4 = movie.imdb_score < 5
criteria5 = movie.content_rating == 'R'
criteria6 = (movie.title_year >= 2000) & (movie.title_year <= 2010 ) 
criteria_final2 = (criteria4 & criteria5 & criteria6)

final = criteria_final1 | criteria_final2
final


# criteria_final1
# criteria_final2
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 4911    False
# 4912    False
# 4913    False
# 4914    False
# 4915    False
# Length: 4916, dtype: bool

# %%
employee = pd.read_csv(r'W:\Users\sardo\OneDrive\Desktop\Maab and Data Analytics\Phyton-Sardor\lesson-23\employee.csv')

# %%
employee
# Out:
#       UNIQUE_ID               POSITION_TITLE                     DEPARTMENT  \
# 0             0  ASSISTANT DIRECTOR (EX LVL)    Municipal Courts Department
# 1             1            LIBRARY ASSISTANT                        Library
# 2             2               POLICE OFFICER  Houston Police Department-HPD
# 3             3            ENGINEER/OPERATOR  Houston Fire Department (HFD)
# 4             4                  ELECTRICIAN    General Services Department
# ...         ...                          ...                            ...
# 1995       1995               POLICE OFFICER  Houston Police Department-HPD
# 1996       1996       COMMUNICATIONS CAPTAIN  Houston Fire Department (HFD)
# 1997       1997               POLICE OFFICER  Houston Police Department-HPD
# 1998       1998               POLICE OFFICER  Houston Police Department-HPD
# 1999       1999                 FIRE FIGHTER  Houston Fire Department (HFD)
#
# ...

# %%
crit1 = employee.DEPARTMENT == 'Houston Police Department-HPD'
crit2 = employee.DEPARTMENT == 'General Services Department'
crit3 = employee.GENDER == 'Female'
crit4 = (employee.BASE_SALARY >= 80000) & (employee.BASE_SALARY <= 120000)
final = (crit1 | crit2) & crit3 & crit4
employee.loc[final,['UNIQUE_ID','DEPARTMENT','HIRE_DATE','BASE_SALARY']]
# Out:
#       UNIQUE_ID                     DEPARTMENT   HIRE_DATE  BASE_SALARY
# 136         136  Houston Police Department-HPD  1991-02-04      81239.0
# 367         367  Houston Police Department-HPD  1993-06-21      86534.0
# 474         474  Houston Police Department-HPD  1989-12-11      91181.0
# 513         513  Houston Police Department-HPD  1991-04-11      81239.0
# 564         564  Houston Police Department-HPD  1995-04-10      81239.0
# 595         595  Houston Police Department-HPD  2012-05-01      99953.0
# 937         937  Houston Police Department-HPD  1994-08-29      81239.0
# 954         954  Houston Police Department-HPD  1990-04-23      91181.0
# 1118       1118  Houston Police Department-HPD  1991-08-05     104455.0
# 1519       1519  Houston Police Department-HPD  1993-02-01      91181.0
# 1565       1565  Houston Police Department-HPD  2014-12-11      81239.0
# 1622       1622  Houston Police Department-HPD  1994-01-31      91181.0
